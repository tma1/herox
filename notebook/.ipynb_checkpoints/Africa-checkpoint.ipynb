# %%
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
africa = pd.read_excel('data/Africa_1997-2018_upd-Jul9.xlsx')
africa.head()

# %%
africa.count()
len(africa.YEAR.unique())
# Out:
# 22

# %%
africa_map = gp.read_file('data/Africa_SHP/Africa.shp')
len(africa_map['COUNTRY'].unique())
# Out:
# 52

# %%
africa_map
# Out:
#       ID CODE         COUNTRY  \
# 0      1  ALG         Algeria
# 1      2  ANG          Angola
# 2      3  ANG          Angola
# 3      4  ANG          Angola
# 4      5  ANG          Angola
# 5      6  ANG          Angola
# 6      7  ANG          Angola
# 7      8  ANG          Angola
# 8      9  ANG          Angola
# 9     10  ANG          Angola
# 10    11  ANG          Angola
# 11    12  ANG          Angola
# 12    13  ANG          Angola
# 13    14  ANG          Angola
# 14    15  ANG          Angola
# 15    16  ANG          Angola
# 16    17  ANG          Angola
# 17    18  ANG          Angola
# 18    19  ANG          Angola
# 19    20  BEN           Benin
# 20    21  BOT        Botswana
# 21    22  BUF    Burkina Faso
# 22    23  BUR         Burundi
# 23    24  CAM        Cameroon
# 24    25  CAM        Cameroon
# 25    26  CAM        Cameroon
# 26    27  CAP      Cape Verde
# 27    28  CAP      Cape Verde
# 28    29  CAP      Cape Verde
# 29    30  CAP      Cape Verde
# ..   ...  ...             ...
# 732  733  TAN        Tanzania
# 733  734  TAN        Tanzania
# 734  735  TAN        Tanzania
# 735  736  TAN        Tanzania
# 736  737  TAN        Tanzania
# 737  738  TAN        Tanzania
# 738  739  TAN        Tanzania
# 739  740  TAN        Tanzania
# 740  741  TAN        Tanzania
# 741  742  TAN        Tanzania
# 742  743  TAN        Tanzania
# 743  744  TAN        Tanzania
# 744  745  TAN        Tanzania
# 745  746  TAN        Tanzania
# 746  747  TAN        Tanzania
# 747  748  TAN        Tanzania
# 748  749  TAN        Tanzania
# 749  750  TAN        Tanzania
# 750  751  TAN        Tanzania
# 751  752  TAN        Tanzania
# 752  753  TAN        Tanzania
# 753  754  TOG            Togo
# 754  755  TUN         Tunisia
# 755  756  TUN         Tunisia
# 756  757  TUN         Tunisia
# 757  758  TUN         Tunisia
# 758  759  UGA          Uganda
# 759  760  WES  Western Sahara
# 760  761  ZAM          Zambia
# 761  762  ZIM        Zimbabwe
#
#                                               geometry
# 0    POLYGON ((-5.7636199999979 25.58624999999302, ...
# 1    POLYGON ((13.36632442474365 -8.32172966003418,...
# 2    POLYGON ((12.80576000000292 -4.806490000002668...
# 3    POLYGON ((11.76834011077881 -16.79932975769043...
# 4    POLYGON ((12.89840030670166 -5.988018989562988...
# 5    POLYGON ((12.64216041564941 -6.053876876831055...
# 6    POLYGON ((12.75524044036865 -6.006577014923096...
# 7    POLYGON ((13.19655990600586 -8.827428817749023...
# 8    POLYGON ((13.10711002349854 -8.943852424621582...
# 9    POLYGON ((12.74098968505859 -6.024965763092041...
# 10   POLYGON ((12.84117984771729 -6.017889022827148...
# 11   POLYGON ((12.79843997955322 -5.998322010040283...
# 12   POLYGON ((12.79683017730713 -6.02660608291626,...
# 13   POLYGON ((12.90713024139404 -5.992850780487061...
# 14   POLYGON ((12.78188991546631 -6.007741928100586...
# 15   POLYGON ((12.85151958465576 -5.997198104858398...
# 16   POLYGON ((13.13667964935303 -8.936841011047363...
# 17   POLYGON ((12.94274997711182 -5.964118003845215...
# 18   POLYGON ((13.05451011657715 -8.982731819152832...
# 19   POLYGON ((2.304162627908227 11.6870782605256, ...
# 20   POLYGON ((28.49249000000418 -22.5743000000075,...
# 21   POLYGON ((-4.650179999996908 12.06180999999924...
# 22   POLYGON ((30.36003000001074 -2.353429999999207...
# 23   POLYGON ((11.80219000000216 7.254119999997783,...
# 24   POLYGON ((8.528149999998277 4.666640000003099,...
# 25   POLYGON ((9.641860000003362 3.630870000000868,...
# 26   POLYGON ((-23.47182999999495 14.97245000000112...
# 27   POLYGON ((-25.02324000000954 17.16727999999421...
# 28   POLYGON ((-22.79613100001006 16.22730999998748...
# 29   POLYGON ((-24.29863999999361 14.95133999999962...
# ..                                                 ...
# 732  POLYGON ((39.52949523925781 -7.950462818145752...
# 733  POLYGON ((40.37530136108398 -10.28676223754883...
# 734  POLYGON ((39.59914398193359 -5.246111869812012...
# 735  POLYGON ((39.29556274414062 -6.383101940155029...
# 736  POLYGON ((39.2712287902832 -6.702835083007812,...
# 737  POLYGON ((39.41486358642578 -6.407701969146729...
# 738  POLYGON ((39.33965682983398 -6.433344841003418...
# 739  POLYGON ((39.28619384765625 -7.822391986846924...
# 740  POLYGON ((39.25085830688477 -5.82416820526123,...
# 741  POLYGON ((39.61739349365234 -5.150252819061279...
# 742  POLYGON ((39.67377471923828 -5.463609218597412...
# 743  POLYGON ((39.57632446289062 -9.100119590759277...
# 744  POLYGON ((39.59830093383789 -8.27916431427002,...
# 745  POLYGON ((39.16567230224609 -5.014794826507568...
# 746  POLYGON ((39.25244903564453 -6.655395984649658...
# 747  POLYGON ((39.65692138671875 -5.058082103729248...
# 748  POLYGON ((39.93057250976562 -6.907918930053711...
# 749  POLYGON ((39.58754348754883 -5.36837100982666,...
# 750  POLYGON ((39.27388381958008 -7.806696891784668...
# 751  POLYGON ((40.42349243164062 -10.3813362121582,...
# 752  POLYGON ((39.11712265014648 -5.146537780761719...
# 753  POLYGON ((0.6151530084298429 7.896637789890519...
# 754  POLYGON ((10.15231000000495 37.13290000002598,...
# 755  POLYGON ((10.78882000000158 33.70701999997254,...
# 756  POLYGON ((11.24592000000121 34.82783999998355,...
# 757  POLYGON ((11.12227000000712 34.6746399999829, ...
# 758  POLYGON ((32.75026000000071 -0.997320000000399...
# 759  POLYGON ((-12.0046699999948 25.90734999999404,...
# 760  POLYGON ((28.99886703491211 -13.41067218780518...
# 761  POLYGON ((27.60406080872053 -17.3579740289133,...
#
# [762 rows x 4 columns]

# %%
africa_map.plot()

# %%
africa_map[732:733].plot()
